# %% [markdown]
# # EDA — HotpotQA (placeholder)
#
# **TODO**: dedicated exploratory analysis of HotpotQA dev distractor split.
#
# Twin of `02_eda_fever.ipynb`. Suggested coverage:
# - Question / answer length distributions
# - Comparison vs bridge question types, easy / medium / hard levels
# - Number of supporting facts per question (single vs both hops)
# - Distractor paragraph distribution per example
# - Lexical overlap between answer and gold paragraphs
